# %%
from pywinauto import application

import os
os.environ.update({"__COMPAT_LAYER":"RUnAsInvoker"})
#os.path.join('')

# %%
app=application.Application(backend='win32').start("C:\Program Files (x86)\哈尔滨芯明天科技有限公司\XMTControlComb-XMTControlComb_20210608\XMTControlComb.exe")
# Out:
# <>:1: DeprecationWarning: invalid escape sequence \P
# <>:1: DeprecationWarning: invalid escape sequence \P
# C:\Users\ThinkDIY\AppData\Local\Temp\ipykernel_18020\1423990855.py:1: DeprecationWarning: invalid escape sequence \P
#   app=application.Application(backend='win32').start("C:\Program Files (x86)\哈尔滨芯明天科技有限公司\XMTControlComb-XMTControlComb_20210608\XMTControlComb.exe")
# c:\Users\ThinkDIY\anaconda3\lib\site-packages\pywinauto\application.py:1085: UserWarning: 32-bit application should be automated using 32-bit Python (you use 64-bit Python)
#   warnings.warn(

# %%
app = application.Application().connect(path="C:\Program Files (x86)\哈尔滨芯明天科技有限公司\XMTControlComb-XMTControlComb_20210608\XMTControlComb.exe")

# %%
wnd = app['三路波形发送'] 
wnd.print_control_identifiers()
# Out:
# Control Identifiers:
#
# Dialog - '三路波形发送'    (L385, T712, R1098, B1159)
# ['Dialog', '三路波形发送Dialog', '三路波形发送']
# child_window(title="三路波形发送", class_name="#32770")
#    |
#    | Button - '确定'    (L544, T1020, R632, B1048)
#    | ['确定', '确定Button', 'Button', 'Button0', 'Button1']
#    | child_window(title="确定", class_name="Button")
#    |
#    | Button - '退出本页'    (L847, T1016, R935, B1044)
#    | ['退出本页', 'Button2', '退出本页Button']
#    | child_window(title="退出本页", class_name="Button")
#    |
#    | ComboBox - '正弦波'    (L453, T810, R537, B834)
#    | ['ComboBox', '一路:ComboBox', 'ComboBox0', 'ComboBox1', '一路:ComboBox0', '一路:ComboBox1']
#    | child_window(title="正弦波", class_name="ComboBox")
#    |    |
#    |    | Edit - '正弦波'    (L456, T813, R513, B831)
#    |    | ['一路:Edit', 'Edit', 'Edit0', 'Edit1']
#    |    | child_window(title="正弦波", class_name="Edit")
#    |
#    | Edit - '正弦波'    (L456, T813, R513, B831)
#    | ['一路:Edit', 'Edit', 'Edit0', 'Edit1']
# ...

# %%
wnd['峰峰值Edit'].set_edit_text(10)
wnd['频率Edit0'].set_edit_text(200)
wnd['偏置Edit'].set_edit_text(20)
wnd['发送Button'].click()

# %%
wnd['停止Button'].click()
